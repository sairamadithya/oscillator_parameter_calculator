# %% [markdown]
# # oscillator frequency and feedback resistance calculator

# %%
# method 1- without functions

# %%
print('this project is used to find the operating frequencies and suitable feedback resistance for oscillators.')
print('an oscillator is an electronic circuit capable of generating output signals without any input.')
print('the different options of oscillators available are:')
print('1.RC phase shift  2.Wein bridge')
print('3.Quadranture  4.Square wave')
print('please choose any one of the above')
type_of_filter=input()
if type_of_filter=='RC phase shift':
    print('enter the resistance in ohms')
    R=int(input())
    print('enter the capacitance in farads')
    C=int(input())
    print('enter the input resistance')
    R1= int(input())
    frequency= 0.065/R*C
    feedback_resistance= 29*R1
    print('the oscillating frequency is:',frequency)
    print('the minimum value of feedback resistance is',feedback_resistance)
elif type_of_filter=='Wein bridge':
    print('enter the resistance in ohms')
    R=int(input())
    print('enter the capacitance in farads')
    C=int(input())
    print('enter the input resistance')
    R1= int(input())
    frequency= 0.159/R*C
    feedback_resistance= 2*R1
    print('the oscillating frequency is:',frequency)
    print('the minimum value of feedback resistance is',feedback_resistance)   
elif type_of_filter=='Quadranture':
    print('enter the resistance in ohms')
    R=int(input())
    print('enter the capacitance in farads')
    C=int(input())
    print('enter the input resistance')
    R1= int(input())
    frequency= 0.159/R*C
    feedback_resistance= 1.414*R1
    print('the oscillating frequency is:',frequency)
    print('the minimum value of feedback resistance is',feedback_resistance)    
elif type_of_filter=='square wave':
    print('enter the resistance in ohms')
    R=int(input())
    print('enter the capacitance in farads')
    C=int(input())
    print('enter the input resistance')
    R1= int(input())
    frequency= 0.5/R*C
    feedback_resistance= 1.16*R1
    print('the oscillating frequency is:',frequency)
    print('the minimum value of feedback resistance is',feedback_resistance)   
else:
    print('sorry! will include even more types in future.')    

print("THANK YOU FOR USING THIS!!")
# Out:
# this project is used to find the operating frequencies and suitable feedback resistance for oscillators.
# an oscillator is an electronic circuit capable of generating output signals without any input.
# the different options of oscillators available are:
# 1.RC phase shift  2.Wein bridge
# 3.Quadranture  4.Square wave
# please choose any one of the above
# Wein bridge
# enter the resistance in ohms
# 120
# enter the capacitance in farads
# 120
# enter the input resistance
# 25
# the oscillating frequency is: 0.159
# the minimum value of feedback resistance is 50

# %%
# METHOD 2- USING FUNCTIONS

# %%
def f_RC(R,C):
    frequency= 0.065/R*C
    return frequency
def Rf_RC(R1):
    feedback_resistance= 29*R1
    return feedback_resistance
def f_wein(R,C):
    frequency= 0.159/R*C
    return frequency
def Rf_wein(R1):
    feedback_resistance= 2*R1
    return feedback_resistance
def f_quad(R,C):
    frequency= 0.159/R*C
    return frequency
def Rf_quad(R1):
    feedback_resistance= 1.414*R1
    return feedback_resistance
def f_square(R,C):
    frequency= 0.5/R*C
    return frequency
def Rf_square(R1):
    feedback_resistance= 1.16*R1
    return feedback_resistance
     

 
print('this project is used to find the operating frequencies and suitable feedback resistance for oscillators.')
print('an oscillator is an electronic circuit capable of generating output signals without any input.')
print('the different options of oscillators available are:')
print('1.RC phase shift  2.Wein bridge')
print('3.Quadranture  4.Square wave')
print('please choose any one of the above')
type_of_filter=input()
if type_of_filter=='RC phase shift':
    print('enter the resistance in ohms')
    R=int(input())
    print('enter the capacitance in farads')
    C=int(input())
    print('enter the input resistance')
    R1= int(input())
    freq= f_RC(R,C)
    Rf= Rf_RC(R1)
    print('the oscillating frequency is:',freq)
    print('the minimum value of feedback resistance is',Rf)
elif type_of_filter=='Wein bridge':
    print('enter the resistance in ohms')
    R=int(input())
    print('enter the capacitance in farads')
    C=int(input())
    print('enter the input resistance')
    R1= int(input())
    freq= f_wein(R,C)
    Rf= Rf_wein(R1) 
    print('the oscillating frequency is:',freq)
    print('the minimum value of feedback resistance is',Rf)   
elif type_of_filter=='Quadranture':
    print('enter the resistance in ohms')
    R=int(input())
    print('enter the capacitance in farads')
    C=int(input())
    print('enter the input resistance')
    R1= int(input())
    freq= f_quad(R,C)
    Rf= Rf_quad(R1)
    print('the oscillating frequency is:',freq)
    print('the minimum value of feedback resistance is',Rf)    
elif type_of_filter=='Square wave':
    print('enter the resistance in ohms')
    R=int(input())
    print('enter the capacitance in farads')
    C=int(input())
    print('enter the input resistance')
    R1= int(input())
    freq= f_square(R,C)
    Rf= Rf_square(R1)
    print('the oscillating frequency is:',freq)
    print('the minimum value of feedback resistance is',Rf) 
else:
    print('sorry! will include even more types in future.')
    
print("THANK YOU FOR USING THIS!!")
# Out:
# this project is used to find the operating frequencies and suitable feedback resistance for oscillators.
# an oscillator is an electronic circuit capable of generating output signals without any input.
# the different options of oscillators available are:
# 1.RC phase shift  2.Wein bridge
# 3.Quadranture  4.Square wave
# please choose any one of the above
# rr
# sorry! will include even more types in future.
# THANK YOU FOR USING THIS!!
